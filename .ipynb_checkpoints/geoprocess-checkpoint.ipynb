# %%
import os
import geopandas as gpd

# %%
buildings = gpd.read_file('BuildingsWithEnergy.geojson')
roads = gpd.read_file('Highways.gpkg')

# %%
boundary = gpd.read_file('SiteBoundary.geojson')
boundary = boundary.to_crs('EPSG:27700')

# %%
boundary.plot()
# Out:
# <AxesSubplot:>

# %%
from shapely.geometry import Point
#limit = Point(53600)

# %%
import momepy as mm

# %%
buildings
# Out:
#        OBJECTID                   fid  featurecod  version versiondat  \
# 0         233.0  osgb1000001800455207       10021        3 2006-04-25
# 1         377.0  osgb1000001802523038       10021        2 2006-02-18
# 2         940.0  osgb1000001802603883       10021        1 2004-07-01
# 3        1595.0  osgb1000001800734082       10021        1 2001-11-05
# 4        1596.0  osgb1000001800734083       10021        1 2001-11-05
# ...         ...                   ...         ...      ...        ...
# 52553  145435.0     osgb1000041820150       10021        7 2022-06-13
# 52554  145436.0     osgb1000042347814       10021        5 2022-06-13
# 52555  145437.0     osgb1000006617652       10021        5 2022-06-09
# 52556  145438.0     osgb1000042348417       10021        7 2022-06-13
# 52557  145439.0     osgb1000041685458       10021        4 2022-06-20
#
#            theme  calculated  \
# 0      Buildings   77.463752
# 1      Buildings   43.200816
# 2      Buildings    2.160696
# ...

# %%
roads
# Out:
#                        TOID alternateidentifier_thematicidentifier_id  \
# 0      osgb4000000030459744                      {5900_5373670178983}
# 1      osgb4000000031090578                      {5900_5378740179166}
# 2      osgb4000000030348641                      {5900_5382930179066}
# 3      osgb4000000031232452                      {5900_5386170179050}
# 4      osgb5000005285209422                                      None
# ...                     ...                                       ...
# 11579  osgb4000000030420349                      {5900_5370400181558}
# 11580  osgb4000000030420517                                      None
# 11581  osgb4000000030475632                      {5900_5369300181065}
# 11582  osgb4000000030475637   {5900_5369350181513,5900_5370400181558}
# 11583  osgb5000005308753576   {5900_5369180181379,5900_5369520181402}
#
#                       identifier_codespace  \
# 0      http://inspire.jrc.ec.europa.eu/ids
# ...

# %%
roads['uID'] = range(len(roads))

# %%
tes_rd = mm.Tessellation(roads, 'uID', boundary, segment = 10)
# Out:
# Inward offset...
# Generating input point array...
# Generating Voronoi diagram...
# Generating GeoDataFrame...
# Dissolving Voronoi polygons...
# ...

# %%
roads_tessellation = tes_rd.tessellation

# %%
ax = roads_tessellation.plot(figsize=(12, 12))
roads.plot(ax=ax, color='k', linewidth=0.4)
# Out:
# <AxesSubplot:>

# %%
buildings = gpd.read_file('BuildingsWithEnergy.geojson')

# %%
buildings['geometry'].area.describe()
# Out:
# count    52558.000000
# mean        95.822641
# std        299.034060
# min          0.103500
# 25%         13.260000
# 50%         41.833550
# 75%         61.438423
# max      11752.571111
# dtype: float64

# %%
buildingsExtracted = buildings[(buildings.TotalFloorArea_sum > 0) | (buildings.geometry.area > 10)]

# %%
buildingsExtracted
# Out:
#        OBJECTID                   fid  featurecod  version versiondat  \
# 0         233.0  osgb1000001800455207       10021        3 2006-04-25
# 1         377.0  osgb1000001802523038       10021        2 2006-02-18
# 3        1595.0  osgb1000001800734082       10021        1 2001-11-05
# 4        1596.0  osgb1000001800734083       10021        1 2001-11-05
# 5        1599.0  osgb1000001800734092       10021        1 2001-11-05
# ...         ...                   ...         ...      ...        ...
# 52553  145435.0     osgb1000041820150       10021        7 2022-06-13
# 52554  145436.0     osgb1000042347814       10021        5 2022-06-13
# 52555  145437.0     osgb1000006617652       10021        5 2022-06-09
# 52556  145438.0     osgb1000042348417       10021        7 2022-06-13
# 52557  145439.0     osgb1000041685458       10021        4 2022-06-20
#
#            theme  calculated  \
# 0      Buildings   77.463752
# 1      Buildings   43.200816
# 3      Buildings   34.456856
# ...

# %%
buildingsExtracted['uID'] = range(len(buildingsExtracted))
# Out:
# C:\Users\liche\anaconda3\lib\site-packages\geopandas\geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
blg_tessellation = tes_blg.tessellation

# %%
ax = blg_tessellation.plot(figsize=(16, 16))
buildingsExtracted.plot(ax=ax, color='k')
ax.set_xlim(537000, 538000)
ax.set_ylim(181000, 182000)
# Out:
# (181000.0, 182000.0)

# %%
from shapely.ops import polygonize
from shapely.geometry import Point
import pandas as pd
limit = boundary.geometry

# %%
gs = gpd.GeoSeries([limit.boundary.values[0]])

# %%
# %%time

barriers = pd.concat([roads.geometry, gs])
# Out:
# Wall time: 3.01 ms
# C:\Users\liche\anaconda3\lib\site-packages\geopandas\array.py:1486: UserWarning: CRS not set for some of the concatenation inputs. Setting output's CRS as OSGB36 / British National Grid (the single non-null crs provided).
#   warnings.warn(

# %%
# %%time
unioned = barriers.unary_union
# Out:
# Wall time: 97.6 ms

# %%
# %%time
polygons = polygonize(unioned)
enclosures = gpd.array.from_shapely(list(polygons), crs=roads.crs)
# Out:
# Wall time: 137 ms

# %%
gpd.GeoSeries(enclosures).plot(figsize=(16, 16), edgecolor='w')
# Out:
# <AxesSubplot:>

# %%
enclosures = mm.enclosures(roads, limit=gs)
# Out:
# C:\Users\liche\anaconda3\lib\site-packages\geopandas\array.py:1486: UserWarning: CRS not set for some of the concatenation inputs. Setting output's CRS as OSGB36 / British National Grid (the single non-null crs provided).
#   warnings.warn(

# %%
enclosed_tess = mm.Tessellation(buildingsExtracted, unique_id='uID', enclosures=enclosures).tessellation
# Out:
# C:\Users\liche\anaconda3\lib\site-packages\momepy\elements.py:457: FutureWarning: The `query_bulk()` method is deprecated and will be removed in GeoPandas 1.0. You can use the `query()` method instead.
#   inp, res = buildings.sindex.query_bulk(
# C:\Users\liche\anaconda3\lib\site-packages\geopandas\array.py:1486: UserWarning: CRS not set for some of the concatenation inputs. Setting output's CRS as OSGB36 / British National Grid (the single non-null crs provided).
#   warnings.warn(

# %%
ax = enclosed_tess.plot(edgecolor='white', figsize=(16, 16))
buildingsExtracted.plot(ax=ax, color='white', alpha=.5)
#ax.set_axis_off()
ax.set_xlim(537500, 537800)
ax.set_ylim(181500, 181800)
# Out:
# (181500.0, 181800.0)

# %%
enclosed_tess.to_file('enclosed_tess_simple.geojson', driver="GeoJSON")

# %%
buildingsExtracted.to_file('buildings_extracted.geojson', driver='GeoJSON')
